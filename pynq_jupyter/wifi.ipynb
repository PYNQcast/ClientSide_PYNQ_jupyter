# %% [markdown]
# Run each cell to ensure board is connected and pinging

# %%
from pynq.lib import Wifi

port = Wifi()

# %%
ssid = "YOUR_HOTSPOT"
pwd = "11112222"
port.connect(ssid, pwd, force=True)
print("done")

# %%
! ping -c 4 8.8.8.8
